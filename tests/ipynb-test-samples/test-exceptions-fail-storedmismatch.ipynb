# %%
# NBVAL_RAISES_EXCEPTION
def foo():
    raise RuntimeError("Foo")
foo()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf9d05c57e16> in <module>()
#       2 def foo():
#       3     raise RuntimeError("Foo")
# ----> 4 foo(a)
#
# NameError: name 'a' is not defined
